# %%
import pandas as pd
import os
import findspark
import pyspark
findspark.init('/usr/lib/spark/')
sc = pyspark.SparkContext.getOrCreate()
from pyspark import SQLContext
from pyspark.sql.functions import mean, min, max
sql_context = SQLContext(sc)
import numpy as np
sql=pyspark.SQLContext(sc)
df=sql.read.option("header","true").csv("s3://hemuawsbucket/notebooks/mortality.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-b8a39cd63203> in <module>()
#       2 import os
#       3 import findspark
# ----> 4 import pyspark
#       5 findspark.init('/usr/lib/spark/')
#       6 sc = pyspark.SparkContext.getOrCreate()
#
# ImportError: No module named 'pyspark'

# %%
df.groupBy('sex').count().collect()
#print('Male deaths in the dataset:',len(s[s=='M']))
#print('Female deaths in the dataset:',len(s[s=='F']))
#df_filtered=df[df['sex']=='M']
#df_age=df_filtered[df_filtered['detail_age']>=60]
#df_age.show()
#df_agem=df_age[df_age['detailed_age']<70]
#df_agem.show().count()

#df_filteredf=df[df['sex']=='F']
#df_agef=df_filteredf[df_filteredf['detail_age']>=60]
#df_agef.show()
#df_agef=df_agef[df_agef['detailed_age']<70]
#df_agef.show()
#print(len(df_agef))
# Out:
# [Row(sex='F', count=13860876),
#  Row(sex='M', count=13859797),
#  Row(sex='sex', count=10)]

# %%
df
# Out:
# DataFrame[resident_status: string, education_1989_revision: string, education_2003_revision: string, education_reporting_flag: string, month_of_death: string, sex: string, detail_age_type: string, detail_age: string, age_substitution_flag: string, age_recode_52: string, age_recode_27: string, age_recode_12: string, infant_age_recode_22: string, place_of_death_and_decedents_status: string, marital_status: string, day_of_week_of_death: string, current_data_year: string, injury_at_work: string, manner_of_death: string, method_of_disposition: string, autopsy: string, activity_code: string, place_of_injury_for_causes_w00_y34_except_y06_and_y07_: string, icd_code_10th_revision: string, 358_cause_recode: string, 113_cause_recode: string, 130_infant_cause_recode: string, 39_cause_recode: string, number_of_entity_axis_conditions: string, entity_condition_1: string, entity_condition_2: string, entity_condition_3: string, entity_condition_4: string, entity_condition_5: string, entity_condition_
# ...

# %%
df1=df[df['detail_age']>=60]
filter_df=df1[df1['detail_age']<70]
filter_df.groupBy('sex').count().collect()
# Out:
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/py4j-src.zip/py4j/java_gateway.py", line 1035, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/py4j-src.zip/py4j/java_gateway.py", line 883, in send_command
#     response = connection.send_command(command)
#   File "/usr/lib/spark/python/lib/py4j-src.zip/py4j/java_gateway.py", line 1040, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-27-30eca606d896> in <module>()
# ...

# %%
from pyspark.sql.functions import *
year_month=df['month_of_death']
df.groupBy('month_of_death').count().collect()
# Out:
# [Row(month_of_death='07', count=2205194),
#  Row(month_of_death='11', count=2285476),
#  Row(month_of_death='01', count=2571615),
#  Row(month_of_death='09', count=2146811),
#  Row(month_of_death='05', count=2278865),
#  Row(month_of_death='08', count=2191365),
#  Row(month_of_death='03', count=2494294),
#  Row(month_of_death='02', count=2324679),
#  Row(month_of_death='06', count=2154291),
#  Row(month_of_death='10', count=2292374),
#  Row(month_of_death='12', count=2479590),
#  Row(month_of_death='04', count=2296119),
#  Row(month_of_death='month_of_death', count=10)]

# %%
df.groupBy('manner_of_death').count().collect()
# Out:
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:35308)
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/py4j-src.zip/py4j/java_gateway.py", line 827, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/py4j-src.zip/py4j/java_gateway.py", line 963, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/lib/spark/python/lib/py4j-src.zip/py4j/java_gateway.py in _get_connection(self)
#     826         try:
# --> 827             connection = self.deque.pop()
#     828         except IndexError:
#
# ...
